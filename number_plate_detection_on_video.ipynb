# %%
import zipfile
zip = zipfile.ZipFile('/content/License Plate Recognition.v6i.yolov11.zip')

# %%
zip.extractall()

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 30.4 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model  = YOLO('yolo11n.pt')

# %%
model.train(data="/content/data.yaml",epochs=15)
# Out:
# Ultralytics 8.3.245 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model.save('best.pt')

# %%
trainedModel = YOLO('/content/best.pt')

# %%
from IPython.display import  Image
Image("/content/test/images/uQmeLCqsF8aVIp37gjARAE6zZTXZacFDpXS7OzSBIg0_jpeg_jpg.rf.afd4b9cd8e9452f9fd6e406ae37f49d2.jpg")

# %%
pred = trainedModel.predict("/content/test/images/uQmeLCqsF8aVIp37gjARAE6zZTXZacFDpXS7OzSBIg0_jpeg_jpg.rf.afd4b9cd8e9452f9fd6e406ae37f49d2.jpg")
# Out:
# image 1/1 /content/test/images/uQmeLCqsF8aVIp37gjARAE6zZTXZacFDpXS7OzSBIg0_jpeg_jpg.rf.afd4b9cd8e9452f9fd6e406ae37f49d2.jpg: 640x640 3 License-Plates, 10.9ms
# Speed: 3.3ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)

# %%
pred[0].show()
# Out:
# <PIL.Image.Image image mode=RGB size=416x416>

# %%
pred = trainedModel.predict("/content/test/images/i_jpg.rf.d359fdf4c74387031f6e9656cad2bc63.jpg")
pred[0].show()
# Out:
# image 1/1 /content/test/images/i_jpg.rf.d359fdf4c74387031f6e9656cad2bc63.jpg: 640x640 2 License-Plates, 10.6ms
# Speed: 3.3ms preprocess, 10.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=416x416>

# %%
pred = trainedModel.predict("/content/test/images/i_jpg.rf.016314b10b92b8d263893581779f5961.jpg")
pred[0].show()
# Out:
# image 1/1 /content/test/images/i_jpg.rf.016314b10b92b8d263893581779f5961.jpg: 640x640 2 License-Plates, 11.3ms
# Speed: 2.6ms preprocess, 11.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=416x416>

# %%
from IPython.display import Video

# %%
Video('/content/WhatsApp Video 2025-12-23 at 8.13.42 PM.mp4')
# Out:
# <video src="/content/WhatsApp Video 2025-12-23 at 8.13.42 PM.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
trainedModel.predict('/content/WhatsApp Video 2025-12-23 at 8.13.42 PM.mp4',save=True)
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/635) /content/WhatsApp Video 2025-12-23 at 8.13.42 PM.mp4: 384x640 2 License-Plates, 51.9ms
# video 1/1 (frame 2/635) /content/WhatsApp Video 2025-12-23 at 8.13.42 PM.mp4: 384x640 2 License-Plates, 8.1ms
# video 1/1 (frame 3/635) /content/WhatsApp Video 2025-12-23 at 8.13.42 PM.mp4: 384x640 2 License-Plates, 8.7ms
# ...

# %%
trainedModel.predict('/content/14747711_2560_1440_30fps.mp4',save=True)
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/655) /content/14747711_2560_1440_30fps.mp4: 384x640 (no detections), 46.3ms
# video 1/1 (frame 2/655) /content/14747711_2560_1440_30fps.mp4: 384x640 1 License-Plate, 38.8ms
# video 1/1 (frame 3/655) /content/14747711_2560_1440_30fps.mp4: 384x640 (no detections), 38.5ms
# video 1/1 (frame 4/655) /content/14747711_2560_1440_30fps.mp4: 384x640 (no detections), 27.8ms
# ...
